# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010136/Computational-Thinking-and-Program-Design/blob/main/%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 期末報告
#
# 組長(學號姓名):A109010076 廖若君
#
# 組員(學號姓名): A109010136 吳幸芳 A109010001 鄭宇修 A109010091 楊子萱

# %% [markdown]
# 題目:

# %% [markdown]
# 百字腳本

# %% [markdown]
# ＃＃電話訂位
# 哈囉，這裡是歐趴鍋訂位專線。
# 敝姓甜，很高興能為您服務。
# 貴賓您好，想請問怎麼稱呼您呢？：宋小姐
# 好的（宋小姐），請問幾位用餐呢？：4位
# 好的（宋小姐），請問都是大人嗎？：不是
# 是：直接跳下一個
# 不是：那請問大人有幾位呢？：2位
# 所以是（2）位大人（總數-大人人數）位小孩嗎？
# 好的（宋小姐），那請問幾點用餐呢？：（5）點
# 好的，那期待（5）點與（4）位貴賓相見喔！
#
#
# ＃＃用餐
# （宋小姐）您好，我是您今天的服務員Bright。
# 請問需要為您做餐點介紹嗎？：需要
#
# 好的，目前我們晚餐時段分為499和599吃到飽，差別在599多了海鮮的品項，而499只有肉品而已，再來我們可以選兩種湯底做鴛鴦鍋，也可以單選一種金額沒有差別。
# 請問今天想吃哪種價位的鍋呢？：599
# 好的，那湯底想要怎麼搭配呢？：鴛鴦鍋
# 那口味是？：麻辣及昆布
# 好的稍後為您送餐，蔬菜、飲料及甜點吧可以自取，取餐時麻煩配戴口罩，用餐時間限時90分鐘，祝您用餐愉快！

# %%
# 電話訂位
print("哈囉，這裡是歐趴鍋訂位專線。")
print("敝姓甜，很高興能為您服務。")
姓名 = input("貴賓您好，想請問怎麼稱呼您呢？")
總人數 =int(input(f"好的{姓名},請問幾位用餐呢？"))
answer1 = input(f"好的{姓名},請問都是大人嗎？，是or不是 ")
if answer1 == "不是" :
    a = int(input("那請問大人有幾位呢？"))
    小孩人數 = int(總人數-a)
    print(f"好的{姓名}，{a}位大人，{小孩人數}位小孩，馬上幫您做安排！")
else:
    print(f"好的{姓名}")
時間 = input(f"{姓名}，請問幾點用餐呢？")
電話 = input(f"好的，可以留一下聯絡方式嗎？")
print(f"好的，那期待{時間}與{總人數}位貴賓相見喔！")

# 進餐廳帶位
input("貴賓您好，請問訂位大名或聯絡方式是？")
print(f"好的{姓名}，馬上為您帶位")

# 點餐
print(f"{姓名}您好，我是您今天的服務員Bright。")
answer2 = input("請問需要為您做餐點介紹嗎？，需要or不需要")
if answer2 == "需要" :
    print(f"好的{姓名}，目前我們晚餐時段分為499和599吃到飽。")
    print("兩者差別在於599多了海鮮的品項，而499只有肉品而已。")
else:
    print(f"好的{姓名}")
if {總人數-a} != 0:
    print("不論何種價位，小孩皆只需要150元。")

answer3 = int(input(f"請問{姓名}今天想吃哪種價位的火鍋呢？499 or 599"))
if answer3 == 499 :
    print(f"好的{姓名}，499的價位有牛肉、豬肉、雞肉、羊肉，需要先怎麼幫您準備？")
else:
    print(f"好的{姓名}，599的價位有白蝦、扇貝、魚、蛤蠣、牛肉、豬肉、雞肉、羊肉，需要先怎麼幫您準備？")
    白蝦 = input("白蝦幾份")
    扇貝 = input("扇貝幾份")
    蛤蠣 = input("蛤蠣幾份")
    魚 = input("魚幾份")
牛肉 = input("牛肉幾份")
豬肉 = input("豬肉幾份")
雞肉 = input("雞肉幾份")
羊肉 = input("羊肉幾份")

print(f"好的{姓名}，再來我們可以選兩種湯底做鴛鴦鍋，也可以單選一種湯底，兩者金額上沒有差別。")
answer4 = input(f"請問湯底想要哪一種選擇呢？鴛鴦鍋 or 單鍋")
print("好的，我們的湯底有昆布湯，麻辣湯，蒜頭雞湯，三鮮湯。")
if answer4 == "鴛鴦鍋" :
    print("請幫我選兩種湯底")
    input("第一種湯底")
    input("第二種湯底")
else:
    input("請幫我選ㄧ種湯底")
print(f"好的{姓名}，稍後為您送餐。")
print("蔬菜、飲料及甜點吧可以自取，取餐時麻煩配戴口罩，用餐時間限時90分鐘，祝您用餐愉快！")

# 用餐

print("您好，這邊幫您整理一下桌面喔！")
answer5 = input("請問有需要加湯嗎？，需要or不需要")
if answer5 == "需要" :
    print("好的！馬上幫您加湯")
else:
    print("好的！")

answer6 = input("那請問有需要加點什麼嗎？，需要or不需要")
if answer6 == "需要" :
    input("請問需要什麼品項及份數呢？")
    print("馬上幫您準備。")
else:
    print("好的，慢用")

# 結帳
answer7 = input("您好，請問今天餐點都還滿意嗎？，滿意or不滿意")
if answer7 == "滿意" :
    print("好的！謝謝您。")
else:
    input("真的相當不好意思，有什嚒需要改進的嗎？可以跟我說。")
    print("好的，我們會改進的")
print("那這邊當您結帳喔。")
print(f"今天是{a}位大人，{總人數-a}位小孩選用{answer3}的套餐。")
大人金額 = int(answer3 * a)
小孩金額 = int(150 * 小孩人數)
print(f"今天總消費是{大人金額+小孩金額}元。")
input("請問刷卡or付現?")
print("好的。")  
print("謝謝光臨！歡迎下次光臨。")
# Out:
# 哈囉，這裡是歐趴鍋訂位專線。
# 敝姓甜，很高興能為您服務。
# 貴賓您好，想請問怎麼稱呼您呢？ben
# 好的ben,請問幾位用餐呢？4
# 好的ben,請問都是大人嗎？，是or不是 不是
# 那請問大人有幾位呢？2
# 好的ben，2位大人，2位小孩，馬上幫您做安排！
# ben，請問幾點用餐呢？5
# 好的，可以留一下聯絡方式嗎？0911111111
# 好的，那期待5與4位貴賓相見喔！
# 貴賓您好，請問訂位大名或聯絡方式是？0911111111
# 好的ben，馬上為您帶位
# ben您好，我是您今天的服務員Bright。
# 請問需要為您做餐點介紹嗎？，需要or不需要不需要
# 好的ben
# 不論何種價位，小孩皆只需要150元。
# 請問ben今天想吃哪種價位的火鍋呢？499 or 599499
# 好的ben，499的價位有牛肉、豬肉、雞肉、羊肉，需要先怎麼幫您準備？
# 牛肉幾份
# 豬肉幾份1
# 雞肉幾份1
# 羊肉幾份1
# 好的ben，再來我們可以選兩種湯底做鴛鴦鍋，也可以單選一種湯底，兩者金額上沒有差別。
# 請問湯底想要哪一種選擇呢？鴛鴦鍋 or 單鍋鴛鴦鍋
# 好的，我們的湯底有昆布湯，麻辣湯，蒜頭雞湯，三鮮湯。
# 請幫我選兩種湯底
# 第一種湯底麻辣
# 第二種湯底三鮮
# 好的ben，稍後為您送餐。
# 蔬菜、飲料及甜點吧可以自取，取餐時麻煩配戴口罩，用餐時間限時90分鐘，祝您用餐愉快！
# 您好，這邊幫您整理一下桌面喔！
# 請問有需要加湯嗎？，需要or不需要不需要
# 好的！
# 那請問有需要加點什麼嗎？，需要or不需要不需要
# 好的，慢用
# 您好，請問今天餐點都還滿意嗎？，滿意or不滿意滿意
# 好的！謝謝您。
# 那這邊當您結帳喔。
# 今天是2位大人，2位小孩選用499的套餐。
# 今天總消費是1298元。
